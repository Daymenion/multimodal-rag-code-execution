# %% [markdown]
# # Research CoPilot
# ## Multimodal RAG with Code Execution (RAG-CE)
#
# This notebook will demo the capabilities of the solution. In the below cells, we will ingest PDF documents that are located in the `cases` directory. Then we will generate questions based on **all** the information extracted from the 2 case documents. Then, with our multimodal Search that is supported by the Code Interpreter, we will generate potential answers to these questions and rate the ground truth vs the generated answer.
#
# This notebook is for demo purposes only, and therefore we will ignore the bias in the the below demo: by generating questions based on the extracted contents of the documents, this introduces a bias, since the questions are only limited to what the solution already has ingested. But again, this is for demo only.

# %% [markdown]
# ### Ingest the Directory
# Import Python packages, and ingest the PDF directory.

# %%
# %load_ext autoreload
# %autoreload 2


import sys
sys.path.append('..\\code')


import os
from dotenv import load_dotenv
load_dotenv()

from IPython.display import display, Markdown, HTML
from PIL import Image
from doc_utils import *
from processor import *


def show_img(img_path, width = None):
    if width is not None:
        display(HTML(f'<img src="{img_path}" width={width}>'))  
    else:
        display(Image.open(img_path))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
doc_path = r"sample_data\minion-tech.pdf"

ingestion_params_dict = {
        "index_name" : 'indexer_test',
        "delete_existing_output_dir": True,
        "processing_mode_pdf" : 'hybrid',
        "doc_path" : doc_path,
        'num_threads': 1
    }

pdf1 = PdfProcessor(ingestion_params_dict)
pdf1.ingest_document()


doc_path = r"sample_data\wile_e_coyote.pdf"

ingestion_params_dict = {
        "index_name" : 'indexer_test',
        "delete_existing_output_dir": False,
        "processing_mode_pdf" : 'hybrid',
        "doc_path" : doc_path,
        'num_threads': 1
    }

pdf2 = PdfProcessor(ingestion_params_dict)
pdf2.ingest_document()
# Out:
# Dirname ..
# Doc Path:  sample_data\minion-tech.pdf
# Doc Proc Directory:  ../indexer_test\minion-tech.pdf
# Ingestion Directory:  ../indexer_test
# Basename:  minion-tech
# Extension:  .pdf
# PDF Path:  ../indexer_test\minion-tech.pdf\minion-tech.pdf
# WARNING ONLY - reading text file: [Errno 2] No such file or directory: '../indexer_test/minion-tech.pdf/minion-tech.dict.txt'
# WARNING ONLY - reading text file: [Errno 2] No such file or directory: '../indexer_test/minion-tech.pdf/minion-tech.dict.txt'
# WARNING ONLY - reading text file: [Errno 2] No such file or directory: '../indexer_test/minion-tech.pdf/minion-tech.processing_plan.txt'
# WARNING ONLY - reading text file: [Errno 2] No such file or directory: '../indexer_test/indexer_test.processing_plan.txt'
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\minion-tech.processing_plan.txt
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\minion-tech.processing_plan.txt
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\stages\minion-tech.create_pdf_chunks.dict.txt
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\minion-tech.dict.txt
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\minion-tech.processing_plan.txt
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\stages\minion-tech.pdf_extract_high_res_chunk_images.dict.txt
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\minion-tech.dict.txt
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\minion-tech.processing_plan.txt
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\stages\minion-tech.delete_pdf_chunks.dict.txt
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\minion-tech.dict.txt
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\minion-tech.txt
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\minion-tech.processing_plan.txt
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\stages\minion-tech.extract_doc_using_doc_int.dict.txt
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\minion-tech.dict.txt
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\text\chunk_0.txt
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\text\chunk_1.txt
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\text\chunk_2.txt
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\text\chunk_3.txt
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\text\chunk_4.txt
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\text\chunk_5.txt
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\text\chunk_6.txt
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\text\chunk_7.txt
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\text\chunk_8.txt
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\text\chunk_9.txt
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\text\chunk_10.txt
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\text\chunk_11.txt
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\text\chunk_12.txt
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\minion-tech.processing_plan.txt
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\stages\minion-tech.create_doc_chunks_with_doc_int_markdown.dict.txt
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\minion-tech.dict.txt
# Post-Processing image 1 on chunk 14 using model ds-openai-eastus
# Chunk Dict Images: ['../indexer_test\\minion-tech.pdf\\images\\chunk_1_image_0.png']
# endpoint https://ds-openai-eastus.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2023-12-01-preview
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\images\chunk_1_image_0.txt
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\minion-tech.txt
#
# Calling OpenAI APIs with 1 messages - Model: gpt-4o - Endpoint: https://ds-openai-eastus.openai.azure.com//openai/
#
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\images\chunk_1_image_0.tags.txt
# Post-Processing: Image processed in chunk 14 using ds-openai-eastus
# Post-Processing image 2 on chunk 15 using model ds-openai-eastus
# Chunk Dict Images: ['../indexer_test\\minion-tech.pdf\\images\\chunk_5_image_0.png']
# endpoint https://ds-openai-eastus.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2023-12-01-preview
#
# Calling OpenAI APIs with 2 messages - Model: gpt-4o - Endpoint: https://ds-openai-eastus.openai.azure.com//openai/
#
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\images\chunk_5_image_0.txt
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\images\chunk_5_image_0.mermaid
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\images\chunk_5_image_0.txt
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\minion-tech.txt
#
# Calling OpenAI APIs with 1 messages - Model: gpt-4o - Endpoint: https://ds-openai-eastus.openai.azure.com//openai/
#
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\images\chunk_5_image_0.tags.txt
# Post-Processing: Image processed in chunk 15 using ds-openai-eastus
# Post-Processing image 3 on chunk 16 using model ds-openai-eastus
# Chunk Dict Images: ['../indexer_test\\minion-tech.pdf\\images\\chunk_7_image_0.png']
# endpoint https://ds-openai-eastus.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2023-12-01-preview
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\images\chunk_7_image_0.txt
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\minion-tech.txt
#
# Calling OpenAI APIs with 1 messages - Model: gpt-4o - Endpoint: https://ds-openai-eastus.openai.azure.com//openai/
#
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\images\chunk_7_image_0.tags.txt
# Post-Processing: Image processed in chunk 16 using ds-openai-eastus
# Post-Processing image 4 on chunk 17 using model ds-openai-eastus
# Chunk Dict Images: ['../indexer_test\\minion-tech.pdf\\images\\chunk_9_image_0.png']
# endpoint https://ds-openai-eastus.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2023-12-01-preview
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\images\chunk_9_image_0.txt
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\minion-tech.txt
#
# Calling OpenAI APIs with 1 messages - Model: gpt-4o - Endpoint: https://ds-openai-eastus.openai.azure.com//openai/
#
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\images\chunk_9_image_0.tags.txt
# Post-Processing: Image processed in chunk 17 using ds-openai-eastus
# Post-Processing image 5 on chunk 18 using model ds-openai-eastus
# Chunk Dict Images: ['../indexer_test\\minion-tech.pdf\\images\\chunk_14_image_0.png']
# endpoint https://ds-openai-eastus.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2023-12-01-preview
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\images\chunk_14_image_0.txt
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\minion-tech.txt
#
# Calling OpenAI APIs with 1 messages - Model: gpt-4o - Endpoint: https://ds-openai-eastus.openai.azure.com//openai/
#
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\images\chunk_14_image_0.tags.txt
# Post-Processing: Image processed in chunk 18 using ds-openai-eastus
# Post-Processing image 6 on chunk 19 using model ds-openai-eastus
# Chunk Dict Images: ['../indexer_test\\minion-tech.pdf\\images\\chunk_18_image_0.png']
# endpoint https://ds-openai-eastus.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2023-12-01-preview
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\images\chunk_18_image_0.md
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\images\chunk_18_image_0.py
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\images\chunk_18_image_0.codeblock
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\images\chunk_18_image_0.txt
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\minion-tech.txt
#
# Calling OpenAI APIs with 1 messages - Model: gpt-4o - Endpoint: https://ds-openai-eastus.openai.azure.com//openai/
#
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\images\chunk_18_image_0.tags.txt
# Post-Processing: Image processed in chunk 19 using ds-openai-eastus
# Post-Processing image 7 on chunk 20 using model ds-openai-eastus
# Chunk Dict Images: ['../indexer_test\\minion-tech.pdf\\images\\chunk_20_image_0.png']
# endpoint https://ds-openai-eastus.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2023-12-01-preview
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\images\chunk_20_image_0.md
#
# Calling OpenAI APIs with 2 messages - Model: gpt-4o - Endpoint: https://ds-openai-eastus.openai.azure.com//openai/
#
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\images\chunk_20_image_0.txt
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\images\chunk_20_image_0.py
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\images\chunk_20_image_0.codeblock
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\images\chunk_20_image_0.txt
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\minion-tech.txt
#
# Calling OpenAI APIs with 1 messages - Model: gpt-4o - Endpoint: https://ds-openai-eastus.openai.azure.com//openai/
#
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\images\chunk_20_image_0.tags.txt
# Post-Processing: Image processed in chunk 20 using ds-openai-eastus
# Post-Processing image 8 on chunk 21 using model ds-openai-eastus
# Chunk Dict Images: ['../indexer_test\\minion-tech.pdf\\images\\chunk_21_image_0.png']
# endpoint https://ds-openai-eastus.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2023-12-01-preview
#
# Calling OpenAI APIs with 2 messages - Model: gpt-4o - Endpoint: https://ds-openai-eastus.openai.azure.com//openai/
#
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\images\chunk_21_image_0.txt
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\images\chunk_21_image_0.mermaid
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\images\chunk_21_image_0.txt
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\minion-tech.txt
#
# Calling OpenAI APIs with 1 messages - Model: gpt-4o - Endpoint: https://ds-openai-eastus.openai.azure.com//openai/
#
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\images\chunk_21_image_0.tags.txt
# Post-Processing: Image processed in chunk 21 using ds-openai-eastus
# Post-Processing image 9 on chunk 22 using model ds-openai-eastus
# Chunk Dict Images: ['../indexer_test\\minion-tech.pdf\\images\\chunk_22_image_0.png']
# endpoint https://ds-openai-eastus.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2023-12-01-preview
#
# Calling OpenAI APIs with 2 messages - Model: gpt-4o - Endpoint: https://ds-openai-eastus.openai.azure.com//openai/
#
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\images\chunk_22_image_0.txt
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\images\chunk_22_image_0.mermaid
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\images\chunk_22_image_0.txt
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\minion-tech.txt
#
# Calling OpenAI APIs with 1 messages - Model: gpt-4o - Endpoint: https://ds-openai-eastus.openai.azure.com//openai/
#
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\images\chunk_22_image_0.tags.txt
# Post-Processing: Image processed in chunk 22 using ds-openai-eastus
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\minion-tech.py
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\minion-tech.py
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\minion-tech.processing_plan.txt
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\stages\minion-tech.post_process_images.dict.txt
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\minion-tech.dict.txt
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\minion-tech.processing_plan.txt
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\stages\minion-tech.post_process_tables.dict.txt
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\minion-tech.dict.txt
# GPT4 Tags - Extraction - Processing text 1 on chunk 1 using gpt-4o and endpoint https://ds-openai-eastus.openai.azure.com
# GPT4 Tags - Post-Processing: Generating tags for chunk 1 using ds-openai-eastus
#
# Calling OpenAI APIs with 1 messages - Model: gpt-4o - Endpoint: https://ds-openai-eastus.openai.azure.com//openai/
#
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\text\chunk_0.tags.txt
# GPT4 Tags - Post-Processing: Tags processed in chunk 1 using ds-openai-eastus
# GPT4 Tags - Extraction - Processing text 2 on chunk 2 using gpt-4o and endpoint https://ds-openai-eastus.openai.azure.com
# GPT4 Tags - Post-Processing: Generating tags for chunk 2 using ds-openai-eastus
#
# Calling OpenAI APIs with 1 messages - Model: gpt-4o - Endpoint: https://ds-openai-eastus.openai.azure.com//openai/
#
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\text\chunk_1.tags.txt
# GPT4 Tags - Post-Processing: Tags processed in chunk 2 using ds-openai-eastus
# GPT4 Tags - Extraction - Processing text 3 on chunk 3 using gpt-4o and endpoint https://ds-openai-eastus.openai.azure.com
# GPT4 Tags - Post-Processing: Generating tags for chunk 3 using ds-openai-eastus
#
# Calling OpenAI APIs with 1 messages - Model: gpt-4o - Endpoint: https://ds-openai-eastus.openai.azure.com//openai/
#
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\text\chunk_2.tags.txt
# GPT4 Tags - Post-Processing: Tags processed in chunk 3 using ds-openai-eastus
# GPT4 Tags - Extraction - Processing text 4 on chunk 4 using gpt-4o and endpoint https://ds-openai-eastus.openai.azure.com
# GPT4 Tags - Post-Processing: Generating tags for chunk 4 using ds-openai-eastus
#
# Calling OpenAI APIs with 1 messages - Model: gpt-4o - Endpoint: https://ds-openai-eastus.openai.azure.com//openai/
#
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\text\chunk_3.tags.txt
# GPT4 Tags - Post-Processing: Tags processed in chunk 4 using ds-openai-eastus
# GPT4 Tags - Extraction - Processing text 5 on chunk 5 using gpt-4o and endpoint https://ds-openai-eastus.openai.azure.com
# GPT4 Tags - Post-Processing: Generating tags for chunk 5 using ds-openai-eastus
#
# Calling OpenAI APIs with 1 messages - Model: gpt-4o - Endpoint: https://ds-openai-eastus.openai.azure.com//openai/
#
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\text\chunk_4.tags.txt
# GPT4 Tags - Post-Processing: Tags processed in chunk 5 using ds-openai-eastus
# GPT4 Tags - Extraction - Processing text 6 on chunk 6 using gpt-4o and endpoint https://ds-openai-eastus.openai.azure.com
# GPT4 Tags - Post-Processing: Generating tags for chunk 6 using ds-openai-eastus
#
# Calling OpenAI APIs with 1 messages - Model: gpt-4o - Endpoint: https://ds-openai-eastus.openai.azure.com//openai/
#
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\text\chunk_5.tags.txt
# GPT4 Tags - Post-Processing: Tags processed in chunk 6 using ds-openai-eastus
# GPT4 Tags - Extraction - Processing text 7 on chunk 7 using gpt-4o and endpoint https://ds-openai-eastus.openai.azure.com
# GPT4 Tags - Post-Processing: Generating tags for chunk 7 using ds-openai-eastus
#
# Calling OpenAI APIs with 1 messages - Model: gpt-4o - Endpoint: https://ds-openai-eastus.openai.azure.com//openai/
#
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\text\chunk_6.tags.txt
# GPT4 Tags - Post-Processing: Tags processed in chunk 7 using ds-openai-eastus
# GPT4 Tags - Extraction - Processing text 8 on chunk 8 using gpt-4o and endpoint https://ds-openai-eastus.openai.azure.com
# GPT4 Tags - Post-Processing: Generating tags for chunk 8 using ds-openai-eastus
#
# Calling OpenAI APIs with 1 messages - Model: gpt-4o - Endpoint: https://ds-openai-eastus.openai.azure.com//openai/
#
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\text\chunk_7.tags.txt
# GPT4 Tags - Post-Processing: Tags processed in chunk 8 using ds-openai-eastus
# GPT4 Tags - Extraction - Processing text 9 on chunk 9 using gpt-4o and endpoint https://ds-openai-eastus.openai.azure.com
# GPT4 Tags - Post-Processing: Generating tags for chunk 9 using ds-openai-eastus
#
# Calling OpenAI APIs with 1 messages - Model: gpt-4o - Endpoint: https://ds-openai-eastus.openai.azure.com//openai/
#
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\text\chunk_8.tags.txt
# GPT4 Tags - Post-Processing: Tags processed in chunk 9 using ds-openai-eastus
# GPT4 Tags - Extraction - Processing text 10 on chunk 10 using gpt-4o and endpoint https://ds-openai-eastus.openai.azure.com
# GPT4 Tags - Post-Processing: Generating tags for chunk 10 using ds-openai-eastus
#
# Calling OpenAI APIs with 1 messages - Model: gpt-4o - Endpoint: https://ds-openai-eastus.openai.azure.com//openai/
#
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\text\chunk_9.tags.txt
# GPT4 Tags - Post-Processing: Tags processed in chunk 10 using ds-openai-eastus
# GPT4 Tags - Extraction - Processing text 11 on chunk 11 using gpt-4o and endpoint https://ds-openai-eastus.openai.azure.com
# GPT4 Tags - Post-Processing: Generating tags for chunk 11 using ds-openai-eastus
#
# Calling OpenAI APIs with 1 messages - Model: gpt-4o - Endpoint: https://ds-openai-eastus.openai.azure.com//openai/
#
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\text\chunk_10.tags.txt
# GPT4 Tags - Post-Processing: Tags processed in chunk 11 using ds-openai-eastus
# GPT4 Tags - Extraction - Processing text 12 on chunk 12 using gpt-4o and endpoint https://ds-openai-eastus.openai.azure.com
# GPT4 Tags - Post-Processing: Generating tags for chunk 12 using ds-openai-eastus
#
# Calling OpenAI APIs with 1 messages - Model: gpt-4o - Endpoint: https://ds-openai-eastus.openai.azure.com//openai/
#
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\text\chunk_11.tags.txt
# GPT4 Tags - Post-Processing: Tags processed in chunk 12 using ds-openai-eastus
# GPT4 Tags - Extraction - Processing text 13 on chunk 13 using gpt-4o and endpoint https://ds-openai-eastus.openai.azure.com
# GPT4 Tags - Post-Processing: Generating tags for chunk 13 using ds-openai-eastus
#
# Calling OpenAI APIs with 1 messages - Model: gpt-4o - Endpoint: https://ds-openai-eastus.openai.azure.com//openai/
#
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\text\chunk_12.tags.txt
# GPT4 Tags - Post-Processing: Tags processed in chunk 13 using ds-openai-eastus
# GPT4 Tags - Extraction - Processing text 14 on chunk 14 using gpt-4o and endpoint https://ds-openai-eastus.openai.azure.com
# GPT4 Tags - Extraction - Processing text 15 on chunk 15 using gpt-4o and endpoint https://ds-openai-eastus.openai.azure.com
# GPT4 Tags - Extraction - Processing text 16 on chunk 16 using gpt-4o and endpoint https://ds-openai-eastus.openai.azure.com
# GPT4 Tags - Extraction - Processing text 17 on chunk 17 using gpt-4o and endpoint https://ds-openai-eastus.openai.azure.com
# GPT4 Tags - Extraction - Processing text 18 on chunk 18 using gpt-4o and endpoint https://ds-openai-eastus.openai.azure.com
# GPT4 Tags - Extraction - Processing text 19 on chunk 19 using gpt-4o and endpoint https://ds-openai-eastus.openai.azure.com
# GPT4 Tags - Extraction - Processing text 20 on chunk 20 using gpt-4o and endpoint https://ds-openai-eastus.openai.azure.com
# GPT4 Tags - Extraction - Processing text 21 on chunk 21 using gpt-4o and endpoint https://ds-openai-eastus.openai.azure.com
# GPT4 Tags - Extraction - Processing text 22 on chunk 22 using gpt-4o and endpoint https://ds-openai-eastus.openai.azure.com
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\minion-tech.processing_plan.txt
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\stages\minion-tech.generate_tags_for_all_chunks.dict.txt
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\minion-tech.dict.txt
#
# Calling OpenAI APIs with 2 messages - Model: gpt-4o - Endpoint: https://ds-openai-eastus.openai.azure.com//openai/
#
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\minion-tech.tags.txt
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\minion-tech.processing_plan.txt
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\stages\minion-tech.generate_document_wide_tags.dict.txt
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\minion-tech.dict.txt
#
# Calling OpenAI APIs with 2 messages - Model: gpt-4o - Endpoint: https://ds-openai-eastus.openai.azure.com//openai/
#
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\minion-tech.summary.txt
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\minion-tech.processing_plan.txt
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\stages\minion-tech.generate_document_wide_summary.dict.txt
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\minion-tech.pdf\minion-tech.dict.txt
#
# Metadata:
# {
#     "asset_path": "../indexer_test/minion-tech.pdf/text/chunk_0.txt",
#     "document_path": "../indexer_test/minion-tech.pdf/minion-tech.pdf",
#     "filename": "minion-tech.pdf",
#     "image_file": "",
#     "asset_filename": "../indexer_test/minion-tech.pdf/text/chunk_0.txt",
#     "chunk_number": "0",
#     "type": "text",
#     "document_id": "2044317f-80ac-f5d1-f435-7f1279c96fd6",
#     "python_block": "",
#     "python_code": "",
#     "markdown": "",
#     "mermaid": "",
#     "tags": "Gru's Enterprises, minion-tech.md, 2024-01-06, Freeze Ray, Rocket Boots, Bubble Gun, Felonius Gru, Dr. Nefario, Kevin, Stuart, Villainville, R&D, Financial Analysis, Market Analysis, Manufacturing Process, Supply Chain Management, Human Resources, Investment Needs, Balance Sheet, Cash Flow Statement, Profit and Loss Statement, North America, Europe, Asia, Acme Corp., VillainCon, Gadget Galaxy, Gru's Enterprises specializes in cartoonish \"evil\" weaponry, Gru's Enterprises is located in Villainville, Gru's Enterprises is led by Felonius Gru, Gru's Enterprises' R&D is led by Dr. Nefario, Gru's Enterprises' Head of Operations is Kevin, Gru's Enterprises' CFO is Stuart, Gru's Enterprises' top products include Freeze Ray, Rocket Boots, and Bubble Gun., 2024-01-06, minion-tech.md, Business Analysis Document, Gru's Enterprises, Innovation in Cartoonish \"Evil\" Weaponry, 123 Villain Street, Villainville, EV123, 123-456-7890, contact@grusenterprises.com, www.grusenterprises.com, Financial Analysis Team, Confidential and Proprietary Information, Executive Summary, Business Model, Financial Highlights, Company Overview, History and Background, Mission and Vision, Organizational Structure, Product Portfolio, Key Products, Innovation and R&D, Market Analysis, Target Market, Clientele, Competitive Landscape, Financial Analysis, Revenue Streams, Cost Analysis, Profitability Analysis, Operational Overview, Manufacturing Process, Supply Chain Management, Human Resources, Staffing and Roles, Compensation and Benefits, Strategic Challenges, Market Risks, Future Growth Opportunities",
#     "asset_id": "48b6649d-9b79-892b-b75c-4fb26682b8a4"
# }
#
# WARNING ONLY - reading text file: [Errno 2] No such file or directory: '../indexer_test/minion-tech.pdf/text/chunk_-1.processed.txt'
# WARNING ONLY - reading text file: [Errno 2] No such file or directory: '../indexer_test/minion-tech.pdf/text/chunk_1.processed.txt'
# Asset File ID:  48b6649d-9b79-892b-b75c-4fb26682b8a4
#
# Metadata:
# {
#     "asset_path": "../indexer_test/minion-tech.pdf/text/chunk_1.txt",
#     "document_path": "../indexer_test/minion-tech.pdf/minion-tech.pdf",
#     "filename": "minion-tech.pdf",
#     "image_file": "",
#     "asset_filename": "../indexer_test/minion-tech.pdf/text/chunk_1.txt",
#     "chunk_number": "1",
#     "type": "text",
#     "document_id": "2044317f-80ac-f5d1-f435-7f1279c96fd6",
#     "python_block": "",
#     "python_code": "",
#     "markdown": "",
#     "mermaid": "",
#     "tags": "Gru's Enterprises, minion-tech.md, 2024-01-06, Freeze Ray, Rocket Boots, Bubble Gun, Felonius Gru, Dr. Nefario, Kevin, Stuart, Villainville, R&D, Financial Analysis, Market Analysis, Manufacturing Process, Supply Chain Management, Human Resources, Investment Needs, Balance Sheet, Cash Flow Statement, Profit and Loss Statement, North America, Europe, Asia, Acme Corp., VillainCon, Gadget Galaxy, Gru's Enterprises specializes in cartoonish \"evil\" weaponry, Gru's Enterprises is located in Villainville, Gru's Enterprises is led by Felonius Gru, Gru's Enterprises' R&D is led by Dr. Nefario, Gru's Enterprises' Head of Operations is Kevin, Gru's Enterprises' CFO is Stuart, Gru's Enterprises' top products include Freeze Ray, Rocket Boots, and Bubble Gun., Financial Analysis, Revenue Streams, Cost Analysis, Profitability Analysis, Operational Overview, Manufacturing Process, Supply Chain Management, Human Resources, Staffing and Roles, Compensation and Benefits, Strategic Challenges and Opportunities, Market Risks, Future Growth Opportunities, Investment Appeal, Investment Needs, Return on Investment Projections, Appendices, Financial Statements, Balance Sheet, Cash Flow Statement, Tables, R&D Costs, Best-selling Products Analysis, Top Clients and Purchases, Geographical Distribution of Product Use, Infographics and Diagrams, Organizational Chart, Process Flow Diagrams, Images, R&D Lab, Company Group Photo, Close-ups of Cartoon Weapons, Executive Summary, Overview of Gru's Business Model, Gru's Enterprises, light-hearted villainy, cartoonish evil weapons, niche market, freeze rays, rocket boots, fantasy weaponry, 2024-01-06\n\nGru's Business Model, Gru's Enterprises, cartoonish weapons, niche market enthusiasts, freeze rays, rocket boots, fantasy weaponry, light-hearted villainy, humor and imagination, unique evil weapons",
#     "asset_id": "78655bed-64e3-5e14-3224-024b5f124ca3"
# }
#
# WARNING ONLY - reading text file: [Errno 2] No such file or directory: '../indexer_test/minion-tech.pdf/text/chunk_0.processed.txt'
# WARNING ONLY - reading text file: [Errno 2] No such file or directory: '../indexer_test/minion-tech.pdf/text/chunk_2.processed.txt'
# Asset File ID:  78655bed-64e3-5e14-3224-024b5f124ca3
#
# Metadata:
# {
#     "asset_path": "../indexer_test/minion-tech.pdf/text/chunk_2.txt",
#     "document_path": "../indexer_test/minion-tech.pdf/minion-tech.pdf",
#     "filename": "minion-tech.pdf",
#     "image_file": "",
#     "asset_filename": "../indexer_test/minion-tech.pdf/text/chunk_2.txt",
#     "chunk_number": "2",
#     "type": "text",
#     "document_id": "2044317f-80ac-f5d1-f435-7f1279c96fd6",
#     "python_block": "",
#     "python_code": "",
#     "markdown": "",
#     "mermaid": "",
#     "tags": "Gru's Enterprises, minion-tech.md, 2024-01-06, Freeze Ray, Rocket Boots, Bubble Gun, Felonius Gru, Dr. Nefario, Kevin, Stuart, Villainville, R&D, Financial Analysis, Market Analysis, Manufacturing Process, Supply Chain Management, Human Resources, Investment Needs, Balance Sheet, Cash Flow Statement, Profit and Loss Statement, North America, Europe, Asia, Acme Corp., VillainCon, Gadget Galaxy, Gru's Enterprises specializes in cartoonish \"evil\" weaponry, Gru's Enterprises is located in Villainville, Gru's Enterprises is led by Felonius Gru, Gru's Enterprises' R&D is led by Dr. Nefario, Gru's Enterprises' Head of Operations is Kevin, Gru's Enterprises' CFO is Stuart, Gru's Enterprises' top products include Freeze Ray, Rocket Boots, and Bubble Gun., Executive Summary, Gru's Enterprises, light-hearted villainy, unique cartoonish evil weapons, niche market, enthusiasts, freeze rays, rocket boots, innovation, practical jokes, fantasy weaponry, Total Revenue 2023, $4.2 million, Gross Profit Margin, 40%, Net Profit Margin, 2%, Total Operating Expenses, $3.8 million, EBITDA, $300,000, Current Assets, $2.5 million, Long-term Liabilities, $1.7 million, 2024-01-06, minion-tech.md, Company Overview, History and Background, supervillain Gru, suburban basement, sophisticated weapons, dedication, creativity, Mission and Vision, mischievous joy, humor, imagination, whimsical revolution, Organizational Structure, Felonius Gru, CEO, Dr. Nefario, Lead Scientist, Kevin, Head of Operations, Stuart, Chief Financial Officer, R&D Team, 50 Minions, Manufacturing Team, 75 Minions, Sales and Marketing, 30 Minions, fantastical weaponry market, laughter-inducing weapons, targeted tags, Gru's Business Model, financial highlights, revenue, profit margin, operating expenses, assets, liabilities, company history, mission statement, organizational chart",
#     "asset_id": "933994eb-f64b-8a51-310b-2825fa3373f7"
# }
#
# WARNING ONLY - reading text file: [Errno 2] No such file or directory: '../indexer_test/minion-tech.pdf/text/chunk_1.processed.txt'
# WARNING ONLY - reading text file: [Errno 2] No such file or directory: '../indexer_test/minion-tech.pdf/text/chunk_3.processed.txt'
# Asset File ID:  933994eb-f64b-8a51-310b-2825fa3373f7
#
# Metadata:
# {
#     "asset_path": "../indexer_test/minion-tech.pdf/text/chunk_3.txt",
#     "document_path": "../indexer_test/minion-tech.pdf/minion-tech.pdf",
#     "filename": "minion-tech.pdf",
#     "image_file": "",
#     "asset_filename": "../indexer_test/minion-tech.pdf/text/chunk_3.txt",
#     "chunk_number": "3",
#     "type": "text",
#     "document_id": "2044317f-80ac-f5d1-f435-7f1279c96fd6",
#     "python_block": "",
#     "python_code": "",
#     "markdown": "",
#     "mermaid": "",
#     "tags": "Gru's Enterprises, minion-tech.md, 2024-01-06, Freeze Ray, Rocket Boots, Bubble Gun, Felonius Gru, Dr. Nefario, Kevin, Stuart, Villainville, R&D, Financial Analysis, Market Analysis, Manufacturing Process, Supply Chain Management, Human Resources, Investment Needs, Balance Sheet, Cash Flow Statement, Profit and Loss Statement, North America, Europe, Asia, Acme Corp., VillainCon, Gadget Galaxy, Gru's Enterprises specializes in cartoonish \"evil\" weaponry, Gru's Enterprises is located in Villainville, Gru's Enterprises is led by Felonius Gru, Gru's Enterprises' R&D is led by Dr. Nefario, Gru's Enterprises' Head of Operations is Kevin, Gru's Enterprises' CFO is Stuart, Gru's Enterprises' top products include Freeze Ray, Rocket Boots, and Bubble Gun., Felonius Gru, CEO, Dr. Nefario, Lead Scientist, Kevin, Head of Operations, Stuart, Chief Financial Officer, R&D Team, 50 Minions, Manufacturing Team, 75 Minions, Sales and Marketing, 30 Minions, Freeze Ray, Rocket Boots, Bubble Gun, $600,000, 2024-01-06, Gru's Enterprises, cartoonish weapons, evil weapons, pranks, mock battles, multi-directional propulsion, adventure enthusiasts, oversized bubbles, festive occasions, advanced technology, innovative design, safety, fun experience, R&D budget, pushing boundaries, imagination, technology, target market, children, families, fun gadgets, hobbyists, unique collectibles, domestic markets, international markets, novelty items",
#     "asset_id": "9638eccc-f8ca-4221-9fd6-fa554569911d"
# }
#
# WARNING ONLY - reading text file: [Errno 2] No such file or directory: '../indexer_test/minion-tech.pdf/text/chunk_2.processed.txt'
# WARNING ONLY - reading text file: [Errno 2] No such file or directory: '../indexer_test/minion-tech.pdf/text/chunk_4.processed.txt'
# Asset File ID:  9638eccc-f8ca-4221-9fd6-fa554569911d
#
# Metadata:
# {
#     "asset_path": "../indexer_test/minion-tech.pdf/text/chunk_4.txt",
#     "document_path": "../indexer_test/minion-tech.pdf/minion-tech.pdf",
#     "filename": "minion-tech.pdf",
#     "image_file": "",
#     "asset_filename": "../indexer_test/minion-tech.pdf/text/chunk_4.txt",
#     "chunk_number": "4",
#     "type": "text",
#     "document_id": "2044317f-80ac-f5d1-f435-7f1279c96fd6",
#     "python_block": "",
#     "python_code": "",
#     "markdown": "",
#     "mermaid": "",
#     "tags": "Gru's Enterprises, minion-tech.md, 2024-01-06, Freeze Ray, Rocket Boots, Bubble Gun, Felonius Gru, Dr. Nefario, Kevin, Stuart, Villainville, R&D, Financial Analysis, Market Analysis, Manufacturing Process, Supply Chain Management, Human Resources, Investment Needs, Balance Sheet, Cash Flow Statement, Profit and Loss Statement, North America, Europe, Asia, Acme Corp., VillainCon, Gadget Galaxy, Gru's Enterprises specializes in cartoonish \"evil\" weaponry, Gru's Enterprises is located in Villainville, Gru's Enterprises is led by Felonius Gru, Gru's Enterprises' R&D is led by Dr. Nefario, Gru's Enterprises' Head of Operations is Kevin, Gru's Enterprises' CFO is Stuart, Gru's Enterprises' top products include Freeze Ray, Rocket Boots, and Bubble Gun., Market Analysis, Target Market, Clientele, children, families, fun gadgets, hobbyists, unique collectibles, domestic markets, international markets, novelty items, Competitive Landscape, entertainment sector, novelty sector, brand recognizability, creativity, Financial Analysis, Revenue Streams, direct product sales, online sales, retail partnerships, licensing deals, merchandising, Cost Analysis, Material Costs, $1.2 million, Labor, $1.5 million, minion salaries, Marketing, $300,000, R&D, $600,000, Profitability Analysis, modest profit margin, future growth, profitability, Operational Overview, Manufacturing Process, Design and Prototyping, Dr. Nefario, Material Sourcing, high-quality materials, Assembly, Minions, quality control, Testing, safety, performance criteria\n\nadditional tags: product development, marketing strategy, streamlined efficiency, innovation, brainstorming, sketching, prototypes, durable materials, rigorous testing",
#     "asset_id": "7f01e512-dae7-bcc6-2654-ddba9bdc6076"
# }
#
# WARNING ONLY - reading text file: [Errno 2] No such file or directory: '../indexer_test/minion-tech.pdf/text/chunk_3.processed.txt'
# WARNING ONLY - reading text file: [Errno 2] No such file or directory: '../indexer_test/minion-tech.pdf/text/chunk_5.processed.txt'
# Asset File ID:  7f01e512-dae7-bcc6-2654-ddba9bdc6076
#
# Metadata:
# {
#     "asset_path": "../indexer_test/minion-tech.pdf/text/chunk_5.txt",
#     "document_path": "../indexer_test/minion-tech.pdf/minion-tech.pdf",
#     "filename": "minion-tech.pdf",
#     "image_file": "",
#     "asset_filename": "../indexer_test/minion-tech.pdf/text/chunk_5.txt",
#     "chunk_number": "5",
#     "type": "text",
#     "document_id": "2044317f-80ac-f5d1-f435-7f1279c96fd6",
#     "python_block": "",
#     "python_code": "",
#     "markdown": "",
#     "mermaid": "",
#     "tags": "Gru's Enterprises, minion-tech.md, 2024-01-06, Freeze Ray, Rocket Boots, Bubble Gun, Felonius Gru, Dr. Nefario, Kevin, Stuart, Villainville, R&D, Financial Analysis, Market Analysis, Manufacturing Process, Supply Chain Management, Human Resources, Investment Needs, Balance Sheet, Cash Flow Statement, Profit and Loss Statement, North America, Europe, Asia, Acme Corp., VillainCon, Gadget Galaxy, Gru's Enterprises specializes in cartoonish \"evil\" weaponry, Gru's Enterprises is located in Villainville, Gru's Enterprises is led by Felonius Gru, Gru's Enterprises' R&D is led by Dr. Nefario, Gru's Enterprises' Head of Operations is Kevin, Gru's Enterprises' CFO is Stuart, Gru's Enterprises' top products include Freeze Ray, Rocket Boots, and Bubble Gun., Design and Prototyping, Dr. Nefario, Material Sourcing, Assembly, Minions, Testing, Supply Chain Management, Minion Kevin, Human Resources, Staffing and Roles, Compensation and Benefits, Gru's Enterprises, Strategic Challenges, Market Risks, Future Growth Opportunities, interactive digital experiences, themed entertainment ventures, Strategic partnerships, brand collaborations, 2024-01-06, 150 minions, healthcare, retirement plans, vacation time, novelty market, innovation, adaptability, new markets, product lines, logistics team, quality control standards, safety and performance criteria, cost-effectiveness, quick turnaround times, R&D, manufacturing, sales, creativity, teamwork",
#     "asset_id": "a2c7c267-a343-cce3-ba2c-bf3a12a6280f"
# }
#
# WARNING ONLY - reading text file: [Errno 2] No such file or directory: '../indexer_test/minion-tech.pdf/text/chunk_4.processed.txt'
# WARNING ONLY - reading text file: [Errno 2] No such file or directory: '../indexer_test/minion-tech.pdf/text/chunk_6.processed.txt'
# Asset File ID:  a2c7c267-a343-cce3-ba2c-bf3a12a6280f
#
# Metadata:
# {
#     "asset_path": "../indexer_test/minion-tech.pdf/text/chunk_6.txt",
#     "document_path": "../indexer_test/minion-tech.pdf/minion-tech.pdf",
#     "filename": "minion-tech.pdf",
#     "image_file": "",
#     "asset_filename": "../indexer_test/minion-tech.pdf/text/chunk_6.txt",
#     "chunk_number": "6",
#     "type": "text",
#     "document_id": "2044317f-80ac-f5d1-f435-7f1279c96fd6",
#     "python_block": "",
#     "python_code": "",
#     "markdown": "",
#     "mermaid": "",
#     "tags": "Gru's Enterprises, minion-tech.md, 2024-01-06, Freeze Ray, Rocket Boots, Bubble Gun, Felonius Gru, Dr. Nefario, Kevin, Stuart, Villainville, R&D, Financial Analysis, Market Analysis, Manufacturing Process, Supply Chain Management, Human Resources, Investment Needs, Balance Sheet, Cash Flow Statement, Profit and Loss Statement, North America, Europe, Asia, Acme Corp., VillainCon, Gadget Galaxy, Gru's Enterprises specializes in cartoonish \"evil\" weaponry, Gru's Enterprises is located in Villainville, Gru's Enterprises is led by Felonius Gru, Gru's Enterprises' R&D is led by Dr. Nefario, Gru's Enterprises' Head of Operations is Kevin, Gru's Enterprises' CFO is Stuart, Gru's Enterprises' top products include Freeze Ray, Rocket Boots, and Bubble Gun., novelty market, innovation, adaptability, future growth opportunities, new markets, product lines, interactive digital experiences, themed entertainment ventures, strategic partnerships, brand collaborations, investment appeal, investment needs, $2 million, R&D expansion, $800,000, marketing and branding, $500,000, operational upgrades, $400,000, staff training and development, $300,000, return on investment projections, 25% increase in annual revenue, 15% annual profitability growth, financial statements, balance sheet, assets, liabilities, equity, 2024-01-06, minion-tech.md\n\nadditional tags: market reach, brand recognition, manufacturing efficiency, supply chain management, team innovation, financial return, unique venture, profitability growth, annual revenue increase, new product development",
#     "asset_id": "07ca750e-3723-535f-68fb-1e03cf406674"
# }
#
# WARNING ONLY - reading text file: [Errno 2] No such file or directory: '../indexer_test/minion-tech.pdf/text/chunk_5.processed.txt'
# WARNING ONLY - reading text file: [Errno 2] No such file or directory: '../indexer_test/minion-tech.pdf/text/chunk_7.processed.txt'
# Asset File ID:  07ca750e-3723-535f-68fb-1e03cf406674
#
# Metadata:
# {
#     "asset_path": "../indexer_test/minion-tech.pdf/text/chunk_7.txt",
#     "document_path": "../indexer_test/minion-tech.pdf/minion-tech.pdf",
#     "filename": "minion-tech.pdf",
#     "image_file": "",
#     "asset_filename": "../indexer_test/minion-tech.pdf/text/chunk_7.txt",
#     "chunk_number": "7",
#     "type": "text",
#     "document_id": "2044317f-80ac-f5d1-f435-7f1279c96fd6",
#     "python_block": "",
#     "python_code": "",
#     "markdown": "",
#     "mermaid": "",
#     "tags": "Gru's Enterprises, minion-tech.md, 2024-01-06, Freeze Ray, Rocket Boots, Bubble Gun, Felonius Gru, Dr. Nefario, Kevin, Stuart, Villainville, R&D, Financial Analysis, Market Analysis, Manufacturing Process, Supply Chain Management, Human Resources, Investment Needs, Balance Sheet, Cash Flow Statement, Profit and Loss Statement, North America, Europe, Asia, Acme Corp., VillainCon, Gadget Galaxy, Gru's Enterprises specializes in cartoonish \"evil\" weaponry, Gru's Enterprises is located in Villainville, Gru's Enterprises is led by Felonius Gru, Gru's Enterprises' R&D is led by Dr. Nefario, Gru's Enterprises' Head of Operations is Kevin, Gru's Enterprises' CFO is Stuart, Gru's Enterprises' top products include Freeze Ray, Rocket Boots, and Bubble Gun., 13 / 22, 14 / 22, 15 / 22, minion-tech.md, 2024-01-06, Appendices, Financial Statements, Balance Sheet, Assets, Liabilities, Equity, Cash and Cash Equivalents, $500,000, Accounts Receivable, $300,000, Inventory, $400,000, Prepaid Expenses, $100,000, Property, Plant, and Equipment, $1,200,000, Total Assets, $2,500,000, Liabilities and Equity, Accounts Payable, $300,000, Accrued Liabilities, $200,000, Long-term Debt, $1,700,000, Total Liabilities, $2,200,000, Total Liabilities and Equity, Cash Flow Statement, cash inflows, cash outflows, fiscal year, financial data, financial summary, financial report, financial overview, financial document, financial analysis, financial information",
#     "asset_id": "f0d21b05-284e-6ab7-6a40-d64910cdedc8"
# }
#
# WARNING ONLY - reading text file: [Errno 2] No such file or directory: '../indexer_test/minion-tech.pdf/text/chunk_6.processed.txt'
# WARNING ONLY - reading text file: [Errno 2] No such file or directory: '../indexer_test/minion-tech.pdf/text/chunk_8.processed.txt'
# Asset File ID:  f0d21b05-284e-6ab7-6a40-d64910cdedc8
#
# Metadata:
# {
#     "asset_path": "../indexer_test/minion-tech.pdf/text/chunk_8.txt",
#     "document_path": "../indexer_test/minion-tech.pdf/minion-tech.pdf",
#     "filename": "minion-tech.pdf",
#     "image_file": "",
#     "asset_filename": "../indexer_test/minion-tech.pdf/text/chunk_8.txt",
#     "chunk_number": "8",
#     "type": "text",
#     "document_id": "2044317f-80ac-f5d1-f435-7f1279c96fd6",
#     "python_block": "",
#     "python_code": "",
#     "markdown": "",
#     "mermaid": "",
# ...
#     "document_path": "../indexer_test/wile_e_coyote.pdf/wile_e_coyote.pdf",
#     "filename": "wile_e_coyote.pdf",
#     "image_file": "",
#     "asset_filename": "../indexer_test/wile_e_coyote.pdf/text/chunk_10.txt",
#     "chunk_number": "10",
#     "type": "text",
#     "document_id": "2720f4b8-62bc-898a-7c54-842756faed6b",
#     "python_block": "",
#     "python_code": "",
#     "markdown": "",
#     "mermaid": "",
#     "tags": "Wile E. Coyote, ACME Enterprises, Gru's Enterprises, Investment Proposal, Road Runner, Canyon Bluff, The Desert, TX 78910, 40% Stake, $2 million, January 6, 2024, Revenue Forecast, Financial Projections, Innovative Weapon, Muscle System Analysis, Hierarchy of Weapons, Past Failed Weapons, Coyote's Arsenal, Strategic Partnership, Gru's Weapons, ACME belongs to Wile E. Coyote, Gru's Enterprises is evaluated at $5 million, Canyon Bluff is located in The Desert, TX 78910, Road Runner is pursued by Wile E. Coyote, ACME Enterprises proposes to invest $2 million in Gru's Enterprises., Coyote, Road Runner, Gru, ACME, technology, weapon, trap, collaboration, partnership, investment, financial returns, goal, 2024-01-06, Wile E. Coyote, CEO, ACME Enterprises, Gru's Enterprises, product capabilities, strategic approach, creative, innovative, advanced weapon, practical application, summary, proposal, next steps, contact information, chase, capturing, testing, complex trap, strategic partnership",
#     "asset_id": "f6abdef5-7baf-eeda-d19f-fad987455ff9"
# }
#
# WARNING ONLY - reading text file: [Errno 2] No such file or directory: '../indexer_test/wile_e_coyote.pdf/text/chunk_9.processed.txt'
# WARNING ONLY - reading text file: [Errno 2] No such file or directory: '../indexer_test/wile_e_coyote.pdf/text/chunk_11.processed.txt'
# Asset File ID:  f6abdef5-7baf-eeda-d19f-fad987455ff9
#
# Metadata:
# {
#     "asset_path": "../indexer_test/wile_e_coyote.pdf/images/chunk_1_image_0.txt",
#     "document_path": "../indexer_test/wile_e_coyote.pdf/wile_e_coyote.pdf",
#     "filename": "wile_e_coyote.pdf",
#     "image_file": "../indexer_test/wile_e_coyote.pdf/images/chunk_1_image_0.jpg",
#     "asset_filename": "../indexer_test/wile_e_coyote.pdf/images/chunk_1_image_0.txt",
#     "chunk_number": "1",
#     "type": "image",
#     "document_id": "2720f4b8-62bc-898a-7c54-842756faed6b",
#     "python_block": "",
#     "python_code": "",
#     "markdown": "",
#     "mermaid": "",
#     "tags": "Wile E. Coyote, ACME Enterprises, Gru's Enterprises, Investment Proposal, Road Runner, Canyon Bluff, The Desert, TX 78910, 40% Stake, $2 million, January 6, 2024, Revenue Forecast, Financial Projections, Innovative Weapon, Muscle System Analysis, Hierarchy of Weapons, Past Failed Weapons, Coyote's Arsenal, Strategic Partnership, Gru's Weapons, ACME belongs to Wile E. Coyote, Gru's Enterprises is evaluated at $5 million, Canyon Bluff is located in The Desert, TX 78910, Road Runner is pursued by Wile E. Coyote, ACME Enterprises proposes to invest $2 million in Gru's Enterprises., ACME Enterprises,logo,emblem,cartoon coyote,running coyote,speed,agility,dynamic design,motion lines,branding,playful,creative,efficiency,red background,black and white accents,1995,OTIV\u00c9PITITIVE,ATEL,corporate culture,establishment year,company name,branding element",
#     "asset_id": "8d7544dc-c904-4e07-dec8-a6bfb37db340"
# }
#
# WARNING ONLY - reading text file: [Errno 2] No such file or directory: '../indexer_test/wile_e_coyote.pdf/text/chunk_1.processed.txt'
# Asset File ID:  8d7544dc-c904-4e07-dec8-a6bfb37db340
#
# Metadata:
# {
#     "asset_path": "../indexer_test/wile_e_coyote.pdf/images/chunk_5_image_0.txt",
#     "document_path": "../indexer_test/wile_e_coyote.pdf/wile_e_coyote.pdf",
#     "filename": "wile_e_coyote.pdf",
#     "image_file": "../indexer_test/wile_e_coyote.pdf/images/chunk_5_image_0.jpg",
#     "asset_filename": "../indexer_test/wile_e_coyote.pdf/images/chunk_5_image_0.txt",
#     "chunk_number": "5",
#     "type": "image",
#     "document_id": "2720f4b8-62bc-898a-7c54-842756faed6b",
#     "python_block": "../indexer_test/wile_e_coyote.pdf/images/chunk_5_image_0.codeblock",
#     "python_code": "../indexer_test/wile_e_coyote.pdf/images/chunk_5_image_0.py",
#     "markdown": "",
#     "mermaid": "",
#     "tags": "Wile E. Coyote, ACME Enterprises, Gru's Enterprises, Investment Proposal, Road Runner, Canyon Bluff, The Desert, TX 78910, 40% Stake, $2 million, January 6, 2024, Revenue Forecast, Financial Projections, Innovative Weapon, Muscle System Analysis, Hierarchy of Weapons, Past Failed Weapons, Coyote's Arsenal, Strategic Partnership, Gru's Weapons, ACME belongs to Wile E. Coyote, Gru's Enterprises is evaluated at $5 million, Canyon Bluff is located in The Desert, TX 78910, Road Runner is pursued by Wile E. Coyote, ACME Enterprises proposes to invest $2 million in Gru's Enterprises., Year 2024 Forecast, line chart, monthly forecast, financial metrics, Revenues, Profits, Costs, quantitative data, visual representation, trends, January, February, March, April, May, June, July, August, September, October, November, December, $400,000, $500,000, $300,000, $100,000, $600,000, blue line, green line, orange line, X-Axis, Y-Axis, dollar amounts, increments of $100,000, color coding, table representation, financial forecast, stable profits, fluctuating revenues, fluctuating costs",
#     "asset_id": "dc3630dc-4328-4b87-e9bd-370acdb3e288"
# }
#
# WARNING ONLY - reading text file: [Errno 2] No such file or directory: '../indexer_test/wile_e_coyote.pdf/text/chunk_5.processed.txt'
# Asset File ID:  dc3630dc-4328-4b87-e9bd-370acdb3e288
#
# Metadata:
# {
#     "asset_path": "../indexer_test/wile_e_coyote.pdf/images/chunk_6_image_0.txt",
#     "document_path": "../indexer_test/wile_e_coyote.pdf/wile_e_coyote.pdf",
#     "filename": "wile_e_coyote.pdf",
#     "image_file": "../indexer_test/wile_e_coyote.pdf/images/chunk_6_image_0.jpg",
#     "asset_filename": "../indexer_test/wile_e_coyote.pdf/images/chunk_6_image_0.txt",
#     "chunk_number": "6",
#     "type": "image",
#     "document_id": "2720f4b8-62bc-898a-7c54-842756faed6b",
#     "python_block": "",
#     "python_code": "",
#     "markdown": "",
#     "mermaid": "",
#     "tags": "Wile E. Coyote, ACME Enterprises, Gru's Enterprises, Investment Proposal, Road Runner, Canyon Bluff, The Desert, TX 78910, 40% Stake, $2 million, January 6, 2024, Revenue Forecast, Financial Projections, Innovative Weapon, Muscle System Analysis, Hierarchy of Weapons, Past Failed Weapons, Coyote's Arsenal, Strategic Partnership, Gru's Weapons, ACME belongs to Wile E. Coyote, Gru's Enterprises is evaluated at $5 million, Canyon Bluff is located in The Desert, TX 78910, Road Runner is pursued by Wile E. Coyote, ACME Enterprises proposes to invest $2 million in Gru's Enterprises., API errors, no results, explanation, extraction, data processing, error handling, failure, issue, problem, troubleshooting, debugging, technical difficulties, system malfunction, result generation, explanation generation, API malfunction, extraction failure, error message, system error, technical issue",
#     "asset_id": "41f3cfdd-716d-6bff-46ef-4ed69ad7e47d"
# }
#
# WARNING ONLY - reading text file: [Errno 2] No such file or directory: '../indexer_test/wile_e_coyote.pdf/text/chunk_6.processed.txt'
# Asset File ID:  41f3cfdd-716d-6bff-46ef-4ed69ad7e47d
#
# Metadata:
# {
#     "asset_path": "../indexer_test/wile_e_coyote.pdf/images/chunk_7_image_0.txt",
#     "document_path": "../indexer_test/wile_e_coyote.pdf/wile_e_coyote.pdf",
#     "filename": "wile_e_coyote.pdf",
#     "image_file": "../indexer_test/wile_e_coyote.pdf/images/chunk_7_image_0.jpg",
#     "asset_filename": "../indexer_test/wile_e_coyote.pdf/images/chunk_7_image_0.txt",
#     "chunk_number": "7",
#     "type": "image",
#     "document_id": "2720f4b8-62bc-898a-7c54-842756faed6b",
#     "python_block": "",
#     "python_code": "",
#     "markdown": "",
#     "mermaid": "",
#     "tags": "Wile E. Coyote, ACME Enterprises, Gru's Enterprises, Investment Proposal, Road Runner, Canyon Bluff, The Desert, TX 78910, 40% Stake, $2 million, January 6, 2024, Revenue Forecast, Financial Projections, Innovative Weapon, Muscle System Analysis, Hierarchy of Weapons, Past Failed Weapons, Coyote's Arsenal, Strategic Partnership, Gru's Weapons, ACME belongs to Wile E. Coyote, Gru's Enterprises is evaluated at $5 million, Canyon Bluff is located in The Desert, TX 78910, Road Runner is pursued by Wile E. Coyote, ACME Enterprises proposes to invest $2 million in Gru's Enterprises., muscle system, bird muscle illustration, educational illustration, muscle groups, muscle functions, color-coded muscles, playful language, dynamic running pose, light blue background, whimsical illustration, cactus, rocks, tire, floating objects, small bird, human muscle figure, fast-twitch muscles, fast muscle fibers, muscle molecules, energy efficiency, engaging learning\n\nbird anatomy, muscle anatomy, muscle labeling, educational tool, children's education, artistic illustration, muscle action, muscle system diagram, muscle fibers, muscle efficiency",
#     "asset_id": "67b96586-4921-5e0d-e146-a76cb96e3351"
# }
#
# WARNING ONLY - reading text file: [Errno 2] No such file or directory: '../indexer_test/wile_e_coyote.pdf/text/chunk_7.processed.txt'
# Asset File ID:  67b96586-4921-5e0d-e146-a76cb96e3351
#
# Metadata:
# {
#     "asset_path": "../indexer_test/wile_e_coyote.pdf/images/chunk_9_image_0.txt",
#     "document_path": "../indexer_test/wile_e_coyote.pdf/wile_e_coyote.pdf",
#     "filename": "wile_e_coyote.pdf",
#     "image_file": "../indexer_test/wile_e_coyote.pdf/images/chunk_9_image_0.jpg",
#     "asset_filename": "../indexer_test/wile_e_coyote.pdf/images/chunk_9_image_0.txt",
#     "chunk_number": "9",
#     "type": "image",
#     "document_id": "2720f4b8-62bc-898a-7c54-842756faed6b",
#     "python_block": "",
#     "python_code": "",
#     "markdown": "",
#     "mermaid": "",
#     "tags": "Wile E. Coyote, ACME Enterprises, Gru's Enterprises, Investment Proposal, Road Runner, Canyon Bluff, The Desert, TX 78910, 40% Stake, $2 million, January 6, 2024, Revenue Forecast, Financial Projections, Innovative Weapon, Muscle System Analysis, Hierarchy of Weapons, Past Failed Weapons, Coyote's Arsenal, Strategic Partnership, Gru's Weapons, ACME belongs to Wile E. Coyote, Gru's Enterprises is evaluated at $5 million, Canyon Bluff is located in The Desert, TX 78910, Road Runner is pursued by Wile E. Coyote, ACME Enterprises proposes to invest $2 million in Gru's Enterprises., animated scene, cartoon characters, chase sequence, coyote, bird, mechanical device, weapon, gadget, pursuit, speed, cartoon antics, desert landscape, clear blue sky, cacti, distant mountains, southwestern desert, paved road, yellow dividing line, highway, road, humorous, exaggerated nature, motion lines, brown fur, blue body, purple crest, yellow beak, running motion, determined expression, confident expression\n\nadditional tags: Wile E. Coyote, Road Runner, Warner Bros, Looney Tunes, cartoon chase, desert highway, cartoon humor, cartoon gadget, cartoon weapon, cartoon desert",
#     "asset_id": "a2b06a38-b3d5-fe28-5ac1-e72484dd3d7e"
# }
#
# WARNING ONLY - reading text file: [Errno 2] No such file or directory: '../indexer_test/wile_e_coyote.pdf/text/chunk_9.processed.txt'
# Asset File ID:  a2b06a38-b3d5-fe28-5ac1-e72484dd3d7e
#
# Metadata:
# {
#     "asset_path": "../indexer_test/wile_e_coyote.pdf/images/chunk_10_image_0.txt",
#     "document_path": "../indexer_test/wile_e_coyote.pdf/wile_e_coyote.pdf",
#     "filename": "wile_e_coyote.pdf",
#     "image_file": "../indexer_test/wile_e_coyote.pdf/images/chunk_10_image_0.jpg",
#     "asset_filename": "../indexer_test/wile_e_coyote.pdf/images/chunk_10_image_0.txt",
#     "chunk_number": "10",
#     "type": "image",
#     "document_id": "2720f4b8-62bc-898a-7c54-842756faed6b",
#     "python_block": "",
#     "python_code": "",
#     "markdown": "",
#     "mermaid": "",
#     "tags": "Wile E. Coyote, ACME Enterprises, Gru's Enterprises, Investment Proposal, Road Runner, Canyon Bluff, The Desert, TX 78910, 40% Stake, $2 million, January 6, 2024, Revenue Forecast, Financial Projections, Innovative Weapon, Muscle System Analysis, Hierarchy of Weapons, Past Failed Weapons, Coyote's Arsenal, Strategic Partnership, Gru's Weapons, ACME belongs to Wile E. Coyote, Gru's Enterprises is evaluated at $5 million, Canyon Bluff is located in The Desert, TX 78910, Road Runner is pursued by Wile E. Coyote, ACME Enterprises proposes to invest $2 million in Gru's Enterprises., Wile E. Coyote, Looney Tunes, cartoon character, desert landscape, American Southwest, complex contraption, mechanical components, Road Runner, humor, ingenuity, persistence, failure, ACME, springs, gears, pulleys, control panel, cage, sandy ground, mesas, rock formations, clear blue sky, colorful illustration, over-engineered device, creativity, antics, attempts, catch, detailed illustration, sparse vegetation, focused expression, mischievous expression, digital display, tools, wood, metal, coils, ropes, gauge, typical habitat, repeated failures, humor illustration, creative machine, cartoon antics, mechanical parts, desert environment, cartoon series, animated character, ACME device, cartoon ingenuity, cartoon persistence, cartoon failure, cartoon humor",
#     "asset_id": "27d181ac-0307-fa76-d699-486c615c7a21"
# }
#
# WARNING ONLY - reading text file: [Errno 2] No such file or directory: '../indexer_test/wile_e_coyote.pdf/text/chunk_10.processed.txt'
# Asset File ID:  27d181ac-0307-fa76-d699-486c615c7a21
#
# Metadata:
# {
#     "asset_path": "../indexer_test/wile_e_coyote.pdf/images/chunk_11_image_0.txt",
#     "document_path": "../indexer_test/wile_e_coyote.pdf/wile_e_coyote.pdf",
#     "filename": "wile_e_coyote.pdf",
#     "image_file": "../indexer_test/wile_e_coyote.pdf/images/chunk_11_image_0.jpg",
#     "asset_filename": "../indexer_test/wile_e_coyote.pdf/images/chunk_11_image_0.txt",
#     "chunk_number": "11",
#     "type": "image",
#     "document_id": "2720f4b8-62bc-898a-7c54-842756faed6b",
#     "python_block": "",
#     "python_code": "",
#     "markdown": "",
#     "mermaid": "",
#     "tags": "Wile E. Coyote, ACME Enterprises, Gru's Enterprises, Investment Proposal, Road Runner, Canyon Bluff, The Desert, TX 78910, 40% Stake, $2 million, January 6, 2024, Revenue Forecast, Financial Projections, Innovative Weapon, Muscle System Analysis, Hierarchy of Weapons, Past Failed Weapons, Coyote's Arsenal, Strategic Partnership, Gru's Weapons, ACME belongs to Wile E. Coyote, Gru's Enterprises is evaluated at $5 million, Canyon Bluff is located in The Desert, TX 78910, Road Runner is pursued by Wile E. Coyote, ACME Enterprises proposes to invest $2 million in Gru's Enterprises., cartoon illustration, animated character, futuristic machine, desert landscape, rock formations, exaggerated features, large ears, long snout, bushy tail, excited character, surprised character, complex device, dials, gauges, tubes, barrel-like structure, weapon, scientific instrument, clear blue sky, cacti, rocks, anthropomorphic character, canine features, human-like features, tripod-mounted machine, detailed scene, visual element, humor, engagement, GENE C\n\nadditional tags: cartoon character, desert setting, futuristic device, anthropomorphic animal, scientific equipment, animated scene, character illustration, desert background, rock formations background, cartoon machine",
#     "asset_id": "46b0640d-8e1c-026b-8ada-7c8305c3f9fd"
# }
#
# WARNING ONLY - reading text file: [Errno 2] No such file or directory: '../indexer_test/wile_e_coyote.pdf/text/chunk_11.processed.txt'
# Asset File ID:  46b0640d-8e1c-026b-8ada-7c8305c3f9fd
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\wile_e_coyote.pdf\wile_e_coyote.vecstore.txt
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\wile_e_coyote.pdf\wile_e_coyote.pdf.ingested
# Writing file to full path: d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\indexer_test\downloads\wile_e_coyote.pdf.ingested

# %% [markdown]
# ### Genereate questions based on the ingested output of the case documents
#
# The below uses only 5 prompts to generate questions / answers pairs that are considered "ground truth" answers.

# %%
path_1 = r"..\indexer_test\minion-tech.pdf\minion-tech.txt"
path_2 = r"..\indexer_test\wile_e_coyote.pdf\wile_e_coyote.txt"

text_template = """
Gru's Document: Business Analysis Document for Minion Tech
## START OF GRU'S DOCUMENT
{gru_doc}
## END OF GRU'S DOCUMENT



Wile E. Coyote's Document: Investment Proposal for Gru's Enterprises
## START OF WILE E. COYOTE'S DOCUMENT
{wile_doc}
## END OF WILE E. COYOTE'S DOCUMENT

"""

text = text_template.format(gru_doc = read_asset_file(path_1)[0] , wile_doc = read_asset_file(path_2)[0])

past_questions = []

qna_pairs = recover_json(ask_LLM_with_JSON(general_prompt_template.format(context=text, past_questions=past_questions), temperature = 0.5))
past_questions.extend(qna_pairs['qna_pairs'])
logc("General Q&A", json.dumps(qna_pairs, indent=4))

qna_pairs = recover_json(ask_LLM_with_JSON(specialized_prompt_template.format(context=text, past_questions=past_questions), temperature = 0.5))
past_questions.extend(qna_pairs['qna_pairs'])
logc("Specialized Q&A", json.dumps(qna_pairs, indent=4))

qna_pairs = recover_json(ask_LLM_with_JSON(numerical_prompt_template.format(context=text, past_questions=past_questions), temperature = 0.5))
past_questions.extend(qna_pairs['qna_pairs'])
logc("Numerical Q&A", json.dumps(qna_pairs, indent=4))

qna_pairs = recover_json(ask_LLM_with_JSON(table_prompt_template.format(context=text, past_questions=past_questions), temperature = 0.5))
past_questions.extend(qna_pairs['qna_pairs'])
logc("Tables Q&A", json.dumps(qna_pairs, indent=4))
    
qna_pairs = recover_json(ask_LLM_with_JSON(image_prompt_template.format(context=text, past_questions=past_questions), temperature = 0.5))
past_questions.extend(qna_pairs['qna_pairs'])
logc("Images Q&A", json.dumps(qna_pairs, indent=4))
# Out:
# Calling OpenAI APIs with 2 messages - Model: gpt-4o - Endpoint: https://ds-openai-eastus.openai.azure.com//openai/
#
# Messages: [{'role': 'system', 'content': 'You are a helpful assistant, who helps the user with their query. You are designed to output JSON.'}, {'role': 'user', 'content': '\n\nContext:\n## START OF CONTEXT\n\nGru\'s Document: Business Analysis Document for Minion Tech\n## START OF GRU\'S DOCUMENT\n<!-- PageHeader="2024-01-06" -->\n<!-- PageHeader="minion-tech.md" -->\n\n\n# Business Analysis Document\n\nGru\'s Enterprises: Innovation in Cartoonish "Evil" Weaponry\n\n\n<figure>\n\nGRUI\'S\nENTERPIIRSES\n\n</figure>\n\n\nAddress:\n\n123 Villain Street, Villainville, EV123\n\nContact Information:\n\n· Phone: 123-456-7890\n\n· Email: contact@grusenterprises.com\n\n· Website: www.grusenterprises.com\n\nPrepared by:\n\nGru\'s Enterprises Financial Analysis Team\n\nDate of Preparation:\n\nJanuary 6, 2024\n\n\n## Confidential and Proprietary Information\n\nThis document contains confidential and proprietary information of Gru\'s Enterprises. It is intended solely for\nthe use of the individual or entity to which it is addressed. If you are not the intended recipient, you are\nhereby notified that any use, dissemination, distribution, or copying of this document is strictly prohibited.\n\n<!-- PageNumber="1 / 22" -->\n<!-- PageBreak -->\n\n<!-- PageHeader="minion-tech.md" -->\n<!-- PageHeader="2024-01-06" -->\n<!-- PageHeader="Table of Contents" -->\n\n\n### 1. Executive Summary\n\no Overview of Gru\'s Business Model\n☐\n\no Key Financial Highlights\n☐\n\n\n#### 2. Company Overview\n\no History and Background\n☐\n\no Mission and Vision\n☐\n\n· Organizational Structure\n☐\n\n\n#### 3. Product Portfolio\n\no Description of Key Products\n☐\n\no Innovation and R&D\n☐\n\n\n#### 4. Market Analysis\n\n· Target Market and Clientele\n☐\n\no Competitive Landscape\n☐\n\n\n#### 5. Financial Analysis\n\no Revenue Streams\n☐\n\no Cost Analysis\n☐\n\no Profitability Analysis\n☐\n\n\n##### 6. Operational Overview\n\no Manufacturing Process\n☐\n\n· Supply Chain Management\n☐\n\n\n##### 7. Human Resources\n\no Staffing and Roles\n☐\n\no Compensation and Benefits\n☐\n\n\n##### 8. Strategic Challenges and Opportunities\n\n· Market Risks\n☐\n\no Future Growth Opportunities\n☐\n\n\n##### 9. Investment Appeal\n\no Investment Needs\n☐\n\no Return on Investment Projections\n☐\n\n\n##### 10. Appendices\n\no Financial Statements\n☐\n\nBalance Sheet\n\n<!-- PageNumber="2/ 22" -->\n<!-- PageBreak -->\n\n<!-- PageHeader="minion-tech.md" -->\n<!-- PageHeader="2024-01-06" -->\n\nCash Flow Statement\n\no Tables\n\nR&D Costs\n\nBest-selling Products Analysis\n\nTop Clients and Purchases\n\nGeographical Distribution of Product Use\n\no Infographics and Diagrams\n\n· Organizational Chart\n\nProcess Flow Diagrams\n\n· Images\n\n· R&D Lab\n\nCompany Group Photo\n\nClose-ups of Cartoon Weapons\n\n<!-- PageNumber="3 / 22" -->\n<!-- PageBreak -->\n\n<!-- PageHeader="minion-tech.md" -->\n<!-- PageHeader="2024-01-06" -->\n\n\n# 1. Executive Summary\n\n\n## Overview of Gru\'s Business Model\n\nGru\'s Enterprises, a novel venture in the world of light-hearted villainy, specializes in the design and\nmanufacture of unique, cartoonish "evil" weapons. These products, appealing to a niche market of enthusiasts,\nare crafted with a touch of humor and imagination. Our product range, from freeze rays to rocket boots,\ncombines innovation with practical jokes, providing an unparalleled experience in the realm of fantasy\nweaponry.\n\n\n## Key Financial Highlights\n\n· Total Revenue (2023): $4.2 million\n\n· Gross Profit Margin: 40%\n\n· Net Profit Margin: 2%\n\n· Total Operating Expenses: $3.8 million\n\n· EBITDA: $300,000\n\n· Current Assets: $2.5 million\n\n· Long-term Liabilities: $1.7 million\n\n<!-- PageNumber="4 / 22" -->\n<!-- PageBreak -->\n\n<!-- PageHeader="2024-01-06" -->\n<!-- PageHeader="minion-tech.md" -->\n\n\n# 2. Company Overview\n\n\n## History and Background\n\nFounded by the infamous yet endearing supervillain Gru, our company began as a small workshop in a\nsuburban ...
#
# Calling OpenAI APIs with 2 messages - Model: gpt-4o - Endpoint: https://ds-openai-eastus.openai.azure.com//openai/
#
# Messages: [{'role': 'system', 'content': 'You are a helpful assistant, who helps the user with their query. You are designed to output JSON.'}, {'role': 'user', 'content': '\n\nContext:\n## START OF CONTEXT\n\nGru\'s Document: Business Analysis Document for Minion Tech\n## START OF GRU\'S DOCUMENT\n<!-- PageHeader="2024-01-06" -->\n<!-- PageHeader="minion-tech.md" -->\n\n\n# Business Analysis Document\n\nGru\'s Enterprises: Innovation in Cartoonish "Evil" Weaponry\n\n\n<figure>\n\nGRUI\'S\nENTERPIIRSES\n\n</figure>\n\n\nAddress:\n\n123 Villain Street, Villainville, EV123\n\nContact Information:\n\n· Phone: 123-456-7890\n\n· Email: contact@grusenterprises.com\n\n· Website: www.grusenterprises.com\n\nPrepared by:\n\nGru\'s Enterprises Financial Analysis Team\n\nDate of Preparation:\n\nJanuary 6, 2024\n\n\n## Confidential and Proprietary Information\n\nThis document contains confidential and proprietary information of Gru\'s Enterprises. It is intended solely for\nthe use of the individual or entity to which it is addressed. If you are not the intended recipient, you are\nhereby notified that any use, dissemination, distribution, or copying of this document is strictly prohibited.\n\n<!-- PageNumber="1 / 22" -->\n<!-- PageBreak -->\n\n<!-- PageHeader="minion-tech.md" -->\n<!-- PageHeader="2024-01-06" -->\n<!-- PageHeader="Table of Contents" -->\n\n\n### 1. Executive Summary\n\no Overview of Gru\'s Business Model\n☐\n\no Key Financial Highlights\n☐\n\n\n#### 2. Company Overview\n\no History and Background\n☐\n\no Mission and Vision\n☐\n\n· Organizational Structure\n☐\n\n\n#### 3. Product Portfolio\n\no Description of Key Products\n☐\n\no Innovation and R&D\n☐\n\n\n#### 4. Market Analysis\n\n· Target Market and Clientele\n☐\n\no Competitive Landscape\n☐\n\n\n#### 5. Financial Analysis\n\no Revenue Streams\n☐\n\no Cost Analysis\n☐\n\no Profitability Analysis\n☐\n\n\n##### 6. Operational Overview\n\no Manufacturing Process\n☐\n\n· Supply Chain Management\n☐\n\n\n##### 7. Human Resources\n\no Staffing and Roles\n☐\n\no Compensation and Benefits\n☐\n\n\n##### 8. Strategic Challenges and Opportunities\n\n· Market Risks\n☐\n\no Future Growth Opportunities\n☐\n\n\n##### 9. Investment Appeal\n\no Investment Needs\n☐\n\no Return on Investment Projections\n☐\n\n\n##### 10. Appendices\n\no Financial Statements\n☐\n\nBalance Sheet\n\n<!-- PageNumber="2/ 22" -->\n<!-- PageBreak -->\n\n<!-- PageHeader="minion-tech.md" -->\n<!-- PageHeader="2024-01-06" -->\n\nCash Flow Statement\n\no Tables\n\nR&D Costs\n\nBest-selling Products Analysis\n\nTop Clients and Purchases\n\nGeographical Distribution of Product Use\n\no Infographics and Diagrams\n\n· Organizational Chart\n\nProcess Flow Diagrams\n\n· Images\n\n· R&D Lab\n\nCompany Group Photo\n\nClose-ups of Cartoon Weapons\n\n<!-- PageNumber="3 / 22" -->\n<!-- PageBreak -->\n\n<!-- PageHeader="minion-tech.md" -->\n<!-- PageHeader="2024-01-06" -->\n\n\n# 1. Executive Summary\n\n\n## Overview of Gru\'s Business Model\n\nGru\'s Enterprises, a novel venture in the world of light-hearted villainy, specializes in the design and\nmanufacture of unique, cartoonish "evil" weapons. These products, appealing to a niche market of enthusiasts,\nare crafted with a touch of humor and imagination. Our product range, from freeze rays to rocket boots,\ncombines innovation with practical jokes, providing an unparalleled experience in the realm of fantasy\nweaponry.\n\n\n## Key Financial Highlights\n\n· Total Revenue (2023): $4.2 million\n\n· Gross Profit Margin: 40%\n\n· Net Profit Margin: 2%\n\n· Total Operating Expenses: $3.8 million\n\n· EBITDA: $300,000\n\n· Current Assets: $2.5 million\n\n· Long-term Liabilities: $1.7 million\n\n<!-- PageNumber="4 / 22" -->\n<!-- PageBreak -->\n\n<!-- PageHeader="2024-01-06" -->\n<!-- PageHeader="minion-tech.md" -->\n\n\n# 2. Company Overview\n\n\n## History and Background\n\nFounded by the infamous yet endearing supervillain Gru, our company began as a small workshop in a\nsuburban ...
#
# Calling OpenAI APIs with 2 messages - Model: gpt-4o - Endpoint: https://ds-openai-eastus.openai.azure.com//openai/
#
# Messages: [{'role': 'system', 'content': 'You are a helpful assistant, who helps the user with their query. You are designed to output JSON.'}, {'role': 'user', 'content': '\n\nContext:\n## START OF CONTEXT\n\nGru\'s Document: Business Analysis Document for Minion Tech\n## START OF GRU\'S DOCUMENT\n<!-- PageHeader="2024-01-06" -->\n<!-- PageHeader="minion-tech.md" -->\n\n\n# Business Analysis Document\n\nGru\'s Enterprises: Innovation in Cartoonish "Evil" Weaponry\n\n\n<figure>\n\nGRUI\'S\nENTERPIIRSES\n\n</figure>\n\n\nAddress:\n\n123 Villain Street, Villainville, EV123\n\nContact Information:\n\n· Phone: 123-456-7890\n\n· Email: contact@grusenterprises.com\n\n· Website: www.grusenterprises.com\n\nPrepared by:\n\nGru\'s Enterprises Financial Analysis Team\n\nDate of Preparation:\n\nJanuary 6, 2024\n\n\n## Confidential and Proprietary Information\n\nThis document contains confidential and proprietary information of Gru\'s Enterprises. It is intended solely for\nthe use of the individual or entity to which it is addressed. If you are not the intended recipient, you are\nhereby notified that any use, dissemination, distribution, or copying of this document is strictly prohibited.\n\n<!-- PageNumber="1 / 22" -->\n<!-- PageBreak -->\n\n<!-- PageHeader="minion-tech.md" -->\n<!-- PageHeader="2024-01-06" -->\n<!-- PageHeader="Table of Contents" -->\n\n\n### 1. Executive Summary\n\no Overview of Gru\'s Business Model\n☐\n\no Key Financial Highlights\n☐\n\n\n#### 2. Company Overview\n\no History and Background\n☐\n\no Mission and Vision\n☐\n\n· Organizational Structure\n☐\n\n\n#### 3. Product Portfolio\n\no Description of Key Products\n☐\n\no Innovation and R&D\n☐\n\n\n#### 4. Market Analysis\n\n· Target Market and Clientele\n☐\n\no Competitive Landscape\n☐\n\n\n#### 5. Financial Analysis\n\no Revenue Streams\n☐\n\no Cost Analysis\n☐\n\no Profitability Analysis\n☐\n\n\n##### 6. Operational Overview\n\no Manufacturing Process\n☐\n\n· Supply Chain Management\n☐\n\n\n##### 7. Human Resources\n\no Staffing and Roles\n☐\n\no Compensation and Benefits\n☐\n\n\n##### 8. Strategic Challenges and Opportunities\n\n· Market Risks\n☐\n\no Future Growth Opportunities\n☐\n\n\n##### 9. Investment Appeal\n\no Investment Needs\n☐\n\no Return on Investment Projections\n☐\n\n\n##### 10. Appendices\n\no Financial Statements\n☐\n\nBalance Sheet\n\n<!-- PageNumber="2/ 22" -->\n<!-- PageBreak -->\n\n<!-- PageHeader="minion-tech.md" -->\n<!-- PageHeader="2024-01-06" -->\n\nCash Flow Statement\n\no Tables\n\nR&D Costs\n\nBest-selling Products Analysis\n\nTop Clients and Purchases\n\nGeographical Distribution of Product Use\n\no Infographics and Diagrams\n\n· Organizational Chart\n\nProcess Flow Diagrams\n\n· Images\n\n· R&D Lab\n\nCompany Group Photo\n\nClose-ups of Cartoon Weapons\n\n<!-- PageNumber="3 / 22" -->\n<!-- PageBreak -->\n\n<!-- PageHeader="minion-tech.md" -->\n<!-- PageHeader="2024-01-06" -->\n\n\n# 1. Executive Summary\n\n\n## Overview of Gru\'s Business Model\n\nGru\'s Enterprises, a novel venture in the world of light-hearted villainy, specializes in the design and\nmanufacture of unique, cartoonish "evil" weapons. These products, appealing to a niche market of enthusiasts,\nare crafted with a touch of humor and imagination. Our product range, from freeze rays to rocket boots,\ncombines innovation with practical jokes, providing an unparalleled experience in the realm of fantasy\nweaponry.\n\n\n## Key Financial Highlights\n\n· Total Revenue (2023): $4.2 million\n\n· Gross Profit Margin: 40%\n\n· Net Profit Margin: 2%\n\n· Total Operating Expenses: $3.8 million\n\n· EBITDA: $300,000\n\n· Current Assets: $2.5 million\n\n· Long-term Liabilities: $1.7 million\n\n<!-- PageNumber="4 / 22" -->\n<!-- PageBreak -->\n\n<!-- PageHeader="2024-01-06" -->\n<!-- PageHeader="minion-tech.md" -->\n\n\n# 2. Company Overview\n\n\n## History and Background\n\nFounded by the infamous yet endearing supervillain Gru, our company began as a small workshop in a\nsuburban ...
#
# Calling OpenAI APIs with 2 messages - Model: gpt-4o - Endpoint: https://ds-openai-eastus.openai.azure.com//openai/
#
# Messages: [{'role': 'system', 'content': 'You are a helpful assistant, who helps the user with their query. You are designed to output JSON.'}, {'role': 'user', 'content': '\n\nContext:\n## START OF CONTEXT\n\nGru\'s Document: Business Analysis Document for Minion Tech\n## START OF GRU\'S DOCUMENT\n<!-- PageHeader="2024-01-06" -->\n<!-- PageHeader="minion-tech.md" -->\n\n\n# Business Analysis Document\n\nGru\'s Enterprises: Innovation in Cartoonish "Evil" Weaponry\n\n\n<figure>\n\nGRUI\'S\nENTERPIIRSES\n\n</figure>\n\n\nAddress:\n\n123 Villain Street, Villainville, EV123\n\nContact Information:\n\n· Phone: 123-456-7890\n\n· Email: contact@grusenterprises.com\n\n· Website: www.grusenterprises.com\n\nPrepared by:\n\nGru\'s Enterprises Financial Analysis Team\n\nDate of Preparation:\n\nJanuary 6, 2024\n\n\n## Confidential and Proprietary Information\n\nThis document contains confidential and proprietary information of Gru\'s Enterprises. It is intended solely for\nthe use of the individual or entity to which it is addressed. If you are not the intended recipient, you are\nhereby notified that any use, dissemination, distribution, or copying of this document is strictly prohibited.\n\n<!-- PageNumber="1 / 22" -->\n<!-- PageBreak -->\n\n<!-- PageHeader="minion-tech.md" -->\n<!-- PageHeader="2024-01-06" -->\n<!-- PageHeader="Table of Contents" -->\n\n\n### 1. Executive Summary\n\no Overview of Gru\'s Business Model\n☐\n\no Key Financial Highlights\n☐\n\n\n#### 2. Company Overview\n\no History and Background\n☐\n\no Mission and Vision\n☐\n\n· Organizational Structure\n☐\n\n\n#### 3. Product Portfolio\n\no Description of Key Products\n☐\n\no Innovation and R&D\n☐\n\n\n#### 4. Market Analysis\n\n· Target Market and Clientele\n☐\n\no Competitive Landscape\n☐\n\n\n#### 5. Financial Analysis\n\no Revenue Streams\n☐\n\no Cost Analysis\n☐\n\no Profitability Analysis\n☐\n\n\n##### 6. Operational Overview\n\no Manufacturing Process\n☐\n\n· Supply Chain Management\n☐\n\n\n##### 7. Human Resources\n\no Staffing and Roles\n☐\n\no Compensation and Benefits\n☐\n\n\n##### 8. Strategic Challenges and Opportunities\n\n· Market Risks\n☐\n\no Future Growth Opportunities\n☐\n\n\n##### 9. Investment Appeal\n\no Investment Needs\n☐\n\no Return on Investment Projections\n☐\n\n\n##### 10. Appendices\n\no Financial Statements\n☐\n\nBalance Sheet\n\n<!-- PageNumber="2/ 22" -->\n<!-- PageBreak -->\n\n<!-- PageHeader="minion-tech.md" -->\n<!-- PageHeader="2024-01-06" -->\n\nCash Flow Statement\n\no Tables\n\nR&D Costs\n\nBest-selling Products Analysis\n\nTop Clients and Purchases\n\nGeographical Distribution of Product Use\n\no Infographics and Diagrams\n\n· Organizational Chart\n\nProcess Flow Diagrams\n\n· Images\n\n· R&D Lab\n\nCompany Group Photo\n\nClose-ups of Cartoon Weapons\n\n<!-- PageNumber="3 / 22" -->\n<!-- PageBreak -->\n\n<!-- PageHeader="minion-tech.md" -->\n<!-- PageHeader="2024-01-06" -->\n\n\n# 1. Executive Summary\n\n\n## Overview of Gru\'s Business Model\n\nGru\'s Enterprises, a novel venture in the world of light-hearted villainy, specializes in the design and\nmanufacture of unique, cartoonish "evil" weapons. These products, appealing to a niche market of enthusiasts,\nare crafted with a touch of humor and imagination. Our product range, from freeze rays to rocket boots,\ncombines innovation with practical jokes, providing an unparalleled experience in the realm of fantasy\nweaponry.\n\n\n## Key Financial Highlights\n\n· Total Revenue (2023): $4.2 million\n\n· Gross Profit Margin: 40%\n\n· Net Profit Margin: 2%\n\n· Total Operating Expenses: $3.8 million\n\n· EBITDA: $300,000\n\n· Current Assets: $2.5 million\n\n· Long-term Liabilities: $1.7 million\n\n<!-- PageNumber="4 / 22" -->\n<!-- PageBreak -->\n\n<!-- PageHeader="2024-01-06" -->\n<!-- PageHeader="minion-tech.md" -->\n\n\n# 2. Company Overview\n\n\n## History and Background\n\nFounded by the infamous yet endearing supervillain Gru, our company began as a small workshop in a\nsuburban ...
#
# Calling OpenAI APIs with 2 messages - Model: gpt-4o - Endpoint: https://ds-openai-eastus.openai.azure.com//openai/
#
# Messages: [{'role': 'system', 'content': 'You are a helpful assistant, who helps the user with their query. You are designed to output JSON.'}, {'role': 'user', 'content': '\n\nContext:\n## START OF CONTEXT\n\nGru\'s Document: Business Analysis Document for Minion Tech\n## START OF GRU\'S DOCUMENT\n<!-- PageHeader="2024-01-06" -->\n<!-- PageHeader="minion-tech.md" -->\n\n\n# Business Analysis Document\n\nGru\'s Enterprises: Innovation in Cartoonish "Evil" Weaponry\n\n\n<figure>\n\nGRUI\'S\nENTERPIIRSES\n\n</figure>\n\n\nAddress:\n\n123 Villain Street, Villainville, EV123\n\nContact Information:\n\n· Phone: 123-456-7890\n\n· Email: contact@grusenterprises.com\n\n· Website: www.grusenterprises.com\n\nPrepared by:\n\nGru\'s Enterprises Financial Analysis Team\n\nDate of Preparation:\n\nJanuary 6, 2024\n\n\n## Confidential and Proprietary Information\n\nThis document contains confidential and proprietary information of Gru\'s Enterprises. It is intended solely for\nthe use of the individual or entity to which it is addressed. If you are not the intended recipient, you are\nhereby notified that any use, dissemination, distribution, or copying of this document is strictly prohibited.\n\n<!-- PageNumber="1 / 22" -->\n<!-- PageBreak -->\n\n<!-- PageHeader="minion-tech.md" -->\n<!-- PageHeader="2024-01-06" -->\n<!-- PageHeader="Table of Contents" -->\n\n\n### 1. Executive Summary\n\no Overview of Gru\'s Business Model\n☐\n\no Key Financial Highlights\n☐\n\n\n#### 2. Company Overview\n\no History and Background\n☐\n\no Mission and Vision\n☐\n\n· Organizational Structure\n☐\n\n\n#### 3. Product Portfolio\n\no Description of Key Products\n☐\n\no Innovation and R&D\n☐\n\n\n#### 4. Market Analysis\n\n· Target Market and Clientele\n☐\n\no Competitive Landscape\n☐\n\n\n#### 5. Financial Analysis\n\no Revenue Streams\n☐\n\no Cost Analysis\n☐\n\no Profitability Analysis\n☐\n\n\n##### 6. Operational Overview\n\no Manufacturing Process\n☐\n\n· Supply Chain Management\n☐\n\n\n##### 7. Human Resources\n\no Staffing and Roles\n☐\n\no Compensation and Benefits\n☐\n\n\n##### 8. Strategic Challenges and Opportunities\n\n· Market Risks\n☐\n\no Future Growth Opportunities\n☐\n\n\n##### 9. Investment Appeal\n\no Investment Needs\n☐\n\no Return on Investment Projections\n☐\n\n\n##### 10. Appendices\n\no Financial Statements\n☐\n\nBalance Sheet\n\n<!-- PageNumber="2/ 22" -->\n<!-- PageBreak -->\n\n<!-- PageHeader="minion-tech.md" -->\n<!-- PageHeader="2024-01-06" -->\n\nCash Flow Statement\n\no Tables\n\nR&D Costs\n\nBest-selling Products Analysis\n\nTop Clients and Purchases\n\nGeographical Distribution of Product Use\n\no Infographics and Diagrams\n\n· Organizational Chart\n\nProcess Flow Diagrams\n\n· Images\n\n· R&D Lab\n\nCompany Group Photo\n\nClose-ups of Cartoon Weapons\n\n<!-- PageNumber="3 / 22" -->\n<!-- PageBreak -->\n\n<!-- PageHeader="minion-tech.md" -->\n<!-- PageHeader="2024-01-06" -->\n\n\n# 1. Executive Summary\n\n\n## Overview of Gru\'s Business Model\n\nGru\'s Enterprises, a novel venture in the world of light-hearted villainy, specializes in the design and\nmanufacture of unique, cartoonish "evil" weapons. These products, appealing to a niche market of enthusiasts,\nare crafted with a touch of humor and imagination. Our product range, from freeze rays to rocket boots,\ncombines innovation with practical jokes, providing an unparalleled experience in the realm of fantasy\nweaponry.\n\n\n## Key Financial Highlights\n\n· Total Revenue (2023): $4.2 million\n\n· Gross Profit Margin: 40%\n\n· Net Profit Margin: 2%\n\n· Total Operating Expenses: $3.8 million\n\n· EBITDA: $300,000\n\n· Current Assets: $2.5 million\n\n· Long-term Liabilities: $1.7 million\n\n<!-- PageNumber="4 / 22" -->\n<!-- PageBreak -->\n\n<!-- PageHeader="2024-01-06" -->\n<!-- PageHeader="minion-tech.md" -->\n\n\n# 2. Company Overview\n\n\n## History and Background\n\nFounded by the infamous yet endearing supervillain Gru, our company began as a small workshop in a\nsuburban ...

# %% [markdown]
# ### Generate answers
#
# With our multimodal Search that is potentially supported by the Code Interpreter, we will generate answers to the questions and rate the ground truth vs the generated answer.

# %%
for index, qna_pair in enumerate(past_questions):
    gen_answer, references, _, _ = search(
        qna_pair['question'], 
        top=3, 
        computation_approach = "LocalPythonExec",  ## other options are "NoComputationTextOnly", "Taskweaver", "AssistantsAPI", or "LocalPythonExec"
        computation_decision = "LLM", 
        index_name = "indexer_test",
        vision_support = True,  
        count = False, 
        verbose = False)

    rating = recover_json(ask_LLM_with_JSON(rate_answers_prompt_template.format(question=qna_pair['question'], ground_truth_answer=qna_pair['answer'], generated_answer=gen_answer)))
    rating = int(rating['rating'])
    past_questions[index]['rating'] = rating
    logc("Rating for question " + str(index) + " is --> " + str(rating), 
         f"\nQuestion: {qna_pair['question']}\n{bc.OKCYAN}Ground truth answer: {qna_pair['answer']}\n{bc.MAGENTA}Generated answer: {gen_answer}\n{bc.LIGHT_RED}References: {json.dumps(references, indent=4)}\n\n\n")
# Out:
# Calling OpenAI APIs with 2 messages - Model: gpt-4o - Endpoint: https://ds-openai-eastus.openai.azure.com//openai/
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File c:\Users\simur\anaconda3\envs\mmdoc\Lib\site-packages\tenacity\__init__.py:478, in Retrying.__call__(self, fn, *args, **kwargs)
#     477 try:
# --> 478     result = fn(*args, **kwargs)
#     479 except BaseException:  # noqa: B902
#
# File d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\tutorials\..\code\utils\http_helpers.py:122, in HTTPRequest.post(self, op, headers, body, data, input_url)
#     120     response = requests.post(url, headers=headers)
# --> 122 return self.handle_response(response)
#
# File d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\tutorials\..\code\utils\http_helpers.py:70, in HTTPRequest.handle_response(self, response)
#      69 if response.status_code >= 400:
# ---> 70     raise HTTPError(response.status_code, response_data)
#      72 return response_data
#
# HTTPError: HTTP Error 400: {'error': {'code': 'FeatureNotSupportedInService', 'message': 'Semantic search is not enabled for this service.\r\nParameter name: queryType', 'details': [{'code': 'SemanticQueriesNotAvailable', 'message': 'Semantic search is not enabled for this service.'}]}}
#
# The above exception was the direct cause of the following exception:
#
# RetryError                                Traceback (most recent call last)
# Cell In[8], line 2
#       1 for index, qna_pair in enumerate(past_questions):
# ----> 2     gen_answer, references, _, _ = search(
#       3         qna_pair['question'],
#       4         top=3,
#       5         computation_approach = "Taskweaver",  ## other options are "NoComputationTextOnly", "Taskweaver", "AssistantsAPI", or "LocalPythonExec"
#       6         computation_decision = "LLM",
#       7         index_name = "indexer_test",
#       8         vision_support = False,
#       9         count = False,
#      10         verbose = False)
#      12     rating = recover_json(ask_LLM_with_JSON(rate_answers_prompt_template.format(question=qna_pair['question'], ground_truth_answer=qna_pair['answer'], generated_answer=gen_answer)))
#      13     rating = int(rating['rating'])
#
# File d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\tutorials\..\code\doc_utils.py:2781, in search(query, learnings, top, approx_tag_limit, conversation_history, user_id, computation_approach, computation_decision, vision_support, include_master_py, vector_directory, vector_type, index_name, full_search_output, count, token_limit, temperature, verbose)
#    2779 results = []
#    2780 if vector_type == "AISearch":
# -> 2781     results = aggregate_ai_search(query, index_name, top=top, approx_tag_limit=approx_tag_limit, computation_approach=computation_approach, count=count, temperature=temperature, verbose = verbose)
#    2782     text_results = [result['text'] for result in results] # FIXME
#    2785 ## Limit the results
#    2786 # results = results[:35]
#
# File d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\tutorials\..\code\doc_utils.py:2656, in aggregate_ai_search(query, index_name, top, approx_tag_limit, computation_approach, count, temperature, t_wait, verbose)
#    2653 counts = [count] * num_threads
#    2654 waits = [t_wait] * num_threads
# -> 2656 results = pool.starmap(call_ai_search,  zip(entities, index_names, tops, computation_approaches, counts, waits))
#    2657 max_items = max([len(r) for r in results])
#    2659 query_results = call_ai_search(query, index_name, top=top, computation_approach = computation_approach, count=count)
#
# File c:\Users\simur\anaconda3\envs\mmdoc\Lib\multiprocessing\pool.py:375, in Pool.starmap(self, func, iterable, chunksize)
#     369 def starmap(self, func, iterable, chunksize=None):
#     370     '''
#     371     Like `map()` method but the elements of the `iterable` are expected to
#     372     be iterables as well and will be unpacked as arguments. Hence
#     373     `func` and (a, b) becomes func(a, b).
#     374     '''
# --> 375     return self._map_async(func, iterable, starmapstar, chunksize).get()
#
# File c:\Users\simur\anaconda3\envs\mmdoc\Lib\multiprocessing\pool.py:774, in ApplyResult.get(self, timeout)
#     772     return self._value
#     773 else:
# --> 774     raise self._value
#
# File c:\Users\simur\anaconda3\envs\mmdoc\Lib\multiprocessing\pool.py:125, in worker(inqueue, outqueue, initializer, initargs, maxtasks, wrap_exception)
#     123 job, i, func, args, kwds = task
#     124 try:
# --> 125     result = (True, func(*args, **kwds))
#     126 except Exception as e:
#     127     if wrap_exception and func is not _helper_reraises_exception:
#
# File c:\Users\simur\anaconda3\envs\mmdoc\Lib\multiprocessing\pool.py:51, in starmapstar(args)
#      50 def starmapstar(args):
# ---> 51     return list(itertools.starmap(args[0], args[1]))
#
# File d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\tutorials\..\code\doc_utils.py:2635, in call_ai_search(query, index_name, top, computation_approach, count, t_wait)
#    2632     t = float(random.randrange(1000))/1000.0
#    2633     time.sleep(t)
# -> 2635 results = index.search_documents(query, top=top, count=count)
#    2637 results = results['value']
#    2638 for r in results: del r['vector']
#
# File d:\PROJECTS\COMPANY_PROJECTS\NTT_DATA\multimodal-rag-code-execution\tutorials\..\code\utils\cogsearch_rest.py:347, in CogSearchRestAPI.search_documents(self, search_query, select_fields, filter_query, top, count)
#     325 search_body = {
#     326     "count": count,
#     327     "search": search_query,
#    (...)
#     343     ]
#     344 }
#     346 headers = {'Content-Type': 'application/json', 'api-key': self.api_key}
# --> 347 response = self.post(op='search', headers=headers, body=search_body)
#     348 return response
#
# File c:\Users\simur\anaconda3\envs\mmdoc\Lib\site-packages\tenacity\__init__.py:336, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     334 copy = self.copy()
#     335 wrapped_f.statistics = copy.statistics  # type: ignore[attr-defined]
# --> 336 return copy(f, *args, **kw)
#
# File c:\Users\simur\anaconda3\envs\mmdoc\Lib\site-packages\tenacity\__init__.py:475, in Retrying.__call__(self, fn, *args, **kwargs)
#     473 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     474 while True:
# --> 475     do = self.iter(retry_state=retry_state)
#     476     if isinstance(do, DoAttempt):
#     477         try:
#
# File c:\Users\simur\anaconda3\envs\mmdoc\Lib\site-packages\tenacity\__init__.py:376, in BaseRetrying.iter(self, retry_state)
#     374 result = None
#     375 for action in self.iter_state.actions:
# --> 376     result = action(retry_state)
#     377 return result
#
# File c:\Users\simur\anaconda3\envs\mmdoc\Lib\site-packages\tenacity\__init__.py:419, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     417 if self.reraise:
#     418     raise retry_exc.reraise()
# --> 419 raise retry_exc from fut.exception()
#
# RetryError: RetryError[<Future at 0x2052b96b1d0 state=finished raised HTTPError>]
